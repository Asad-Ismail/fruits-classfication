# %%
import sagemaker
#sagemaker.local.LocalSession
#Use local session for traning locally other wise use session
sess=sagemaker.local.LocalSession()
#sess=sagemaker.Session()
role= sagemaker.get_execution_role()
account =sess.boto_session.client('sts').get_caller_identity()['Account']
region= sess.boto_session.region_name

# %%
# !cat Dockerfile
# Out:
# FROM nvidia/cuda:11.2.1-cudnn8-runtime-ubuntu20.04
# ENV DEBIAN_FRONTEND=noninteractive
# RUN apt-get update && apt-get install -y --no-install-recommends \
# 		ca-certificates \
# 		curl \
# 		netbase \
# 		wget \
#        build-essential \
#         libopencv-dev\
#         libopenblas-dev \
#         nginx
#
# ENV PYTHON_VERSION=3.6
#
# ENV LANG=C.UTF-8 LC_ALL=C.UTF-8
# ENV PATH /opt/conda/bin:$PATH
#
# RUN wget --quiet https://repo.anaconda.com/miniconda/Miniconda3-4.5.12-Linux-x86_64.sh -O ~/miniconda.sh && \
#     /bin/bash ~/miniconda.sh -b -p /opt/conda && \
#     rm ~/miniconda.sh && \
#     /opt/conda/bin/conda install -y python=$PYTHON_VERSION
#
# RUN pip install tensorflow-gpu
#
# #COPY ./tensorflow-2.3.0-cp38-cp38-linux_x86_64.whl /opt/
# #RUN pip install /opt/tensorflow-2.3.0-cp38-cp38-linux_x86_64.whl
# RUN pip install scipy pillow gunicorn==19.9.0 gevent flask
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# COPY ./scripts /opt/program
#
# RUN chmod +x /opt/program/train
# RUN chmod +x /opt/program/serve
#
# WORKDIR /opt/program

# %%
repo_name="k-fruit-class"
image_tag="k-fruits-class-gpu"
base_job_name="k-fruits-cnn"

# %env dockerfile Dockerfile

train_instance_type ="ml.p3.8xlarge"
# Out:
# env: dockerfile=Dockerfile

# %% [markdown]
# ### Below cells sets up enironment variables build dokcer image and push to ECR If the image is already in ECR skip these steps

# %%
# %env account {account}
# %env region {region}
# %env repo_name {repo_name}
# %env image_tag {image_tag}
# Out:
# env: account=470086202700
# env: region=us-east-1
# env: repo_name=k-fruit-class
# env: image_tag=k-fruits-class-gpu

# %%
# %%sh
#
# aws ecr describe-repositories --repository-names $repo_name > /dev/null 2>&1
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name $repo_name > /dev/null
# fi
#
# $(aws ecr get-login --region $region --no-include-email)
# Out:
# Login Succeeded
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %%
# !docker build -t $image_tag -f $dockerfile .
# Out:
# Sending build context to Docker daemon  1.099GB
# Step 1/16 : FROM nvidia/cuda:11.2.1-cudnn8-runtime-ubuntu20.04
# 11.2.1-cudnn8-runtime-ubuntu20.04: Pulling from nvidia/cuda
#
# 3a23efb7: Pulling fs layer
# fc6f11f0: Pulling fs layer
# acd52c6c: Pulling fs layer
# 8932ea2b: Pulling fs layer
# 84e33a63: Pulling fs layer
# 9ffc47b8: Pulling fs layer
# 4e63c139: Pulling fs layer
# ec8eef17: Pulling fs layer
# 36290d35: Pull complete 735MB/735MBkBBAExtracting  251.8MB/735MBExtracting  382.1MB/735MBDigest: sha256:54ee3998c35d5114e68cadbde4fb23af6954d58ba2050fbf5f9dd868a3b52386
# Status: Downloaded newer image for nvidia/cuda:11.2.1-cudnn8-runtime-ubuntu20.04
#  ---> 564cde45cf27
# Step 2/16 : ENV DEBIAN_FRONTEND=noninteractive
#  ---> Running in cd6945fa8245
# Removing intermediate container cd6945fa8245
#  ---> 50715e200771
# Step 3/16 : RUN apt-get update && apt-get install -y --no-install-recommends 		ca-certificates 		curl 		netbase 		wget        build-essential         libopencv-dev        libopenblas-dev         nginx
#  ---> Running in 9701a4818354
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [109 kB]
# Get:2 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [670 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [621 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [165 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [13.3 kB]
# Ign:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Release [697 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release [564 B]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Release.gpg [836 B]
# Get:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release.gpg [833 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-backports InRelease [101 kB]
# Ign:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [366 kB]
# Get:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Packages [2445 B]
# Get:17 http://archive.ubuntu.com/ubuntu focal/restricted amd64 Packages [33.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1275 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [177 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [1029 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [932 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [21.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [198 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [4301 B]
# Fetched 17.4 MB in 2s (7283 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ca-certificates is already the newest version (20210119~20.04.1).
# The following additional packages will be installed:
#   adwaita-icon-theme binutils binutils-common binutils-x86-64-linux-gnu cpp
#   cpp-9 dbus dbus-user-session dconf-gsettings-backend dconf-service dpkg-dev
#   fontconfig fontconfig-config fonts-dejavu-core g++ g++-9 gcc gcc-9
#   gcc-9-base gdal-data glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gtk-update-icon-cache
#   hicolor-icon-theme humanity-icon-theme iproute2 iso-codes libaec0 libaom0
#   libapparmor1 libarchive13 libargon2-1 libarmadillo9 libarpack2 libasan5
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatomic1 libatspi2.0-0
#   libavahi-client3 libavahi-common-data libavahi-common3 libavcodec-dev
#   libavcodec58 libavformat-dev libavformat58 libavresample-dev libavresample4
#   libavutil-dev libavutil56 libbinutils libbluray2 libbrotli1 libbsd0
#   libc-dev-bin libc6 libc6-dev libcairo-gobject2 libcairo2 libcap2 libcap2-bin
#   libcc1-0 libcfitsio8 libcharls2 libchromaprint1 libcodec2-0.9 libcolord2
#   libcrypt-dev libcryptsetup12 libctf-nobfd0 libctf0 libcups2 libcurl3-gnutls
#   libcurl4 libdap25 libdapclient6v5 libdatrie1 libdbus-1-3 libdc1394-22
#   libdc1394-22-dev libdconf1 libdevmapper1.02.1 libdpkg-perl libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libedit2
#   libelf1 libepoxy0 libepsilon1 libevent-2.1-7 libevent-core-2.1-7
#   libevent-pthreads-2.1-7 libexif-dev libexif12 libexpat1 libfabric1
#   libfontconfig1 libfreetype6 libfreexl1 libfribidi0 libfyba0 libgcc-9-dev
#   libgd3 libgdal26 libgdbm-compat4 libgdbm6 libgdcm-dev libgdcm3.0
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-common libgeos-3.8.0 libgeos-c1v5
#   libgeotiff5 libgfortran5 libgif7 libgl1 libgl1-mesa-dri libgl2ps1.4
#   libglapi-mesa libglib2.0-0 libglvnd0 libglx-mesa0 libglx0 libgme0 libgomp1
#   libgphoto2-6 libgphoto2-dev libgphoto2-port12 libgraphite2-3 libgsm1
#   libgssapi-krb5-2 libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libgtk-3-0
#   libgtk-3-common libharfbuzz0b libhdf4-0-alt libhdf5-103 libhdf5-openmpi-103
#   libhwloc-plugins libhwloc15 libibverbs1 libice6 libicu66 libilmbase-dev
#   libilmbase24 libip4tc2 libisl22 libitm1 libjbig-dev libjbig0 libjpeg-dev
#   libjpeg-turbo8 libjpeg-turbo8-dev libjpeg8 libjpeg8-dev libjson-c4
#   libjson-glib-1.0-0 libjson-glib-1.0-common libjsoncpp1 libk5crypto3
#   libkeyutils1 libkmlbase1 libkmldom1 libkmlengine1 libkmod2 libkrb5-3
#   libkrb5support0 liblcms2-2 liblept5 libllvm11 liblsan0 libltdl7 liblzma-dev
#   libminizip1 libmnl0 libmp3lame0 libmpc3 libmpfr6 libmpg123-0
#   libmysqlclient21 libnetcdf-c++4 libnetcdf15 libnghttp2-14
#   libnginx-mod-http-image-filter libnginx-mod-http-xslt-filter
#   libnginx-mod-mail libnginx-mod-stream libnl-3-200 libnl-route-3-200 libnspr4
#   libnss3 libnuma1 libodbc1 libogdi4.1 libogg0 libopenblas-pthread-dev
#   libopenblas0 libopenblas0-pthread libopencv-calib3d-dev libopencv-calib3d4.2
#   libopencv-contrib-dev libopencv-contrib4.2 libopencv-core-dev
#   libopencv-core4.2 libopencv-dnn-dev libopencv-dnn4.2
#   libopencv-features2d-dev libopencv-features2d4.2 libopencv-flann-dev
#   libopencv-flann4.2 libopencv-highgui-dev libopencv-highgui4.2
#   libopencv-imgcodecs-dev libopencv-imgcodecs4.2 libopencv-imgproc-dev
#   libopencv-imgproc4.2 libopencv-ml-dev libopencv-ml4.2
#   libopencv-objdetect-dev libopencv-objdetect4.2 libopencv-photo-dev
#   libopencv-photo4.2 libopencv-shape-dev libopencv-shape4.2
#   libopencv-stitching-dev libopencv-stitching4.2 libopencv-superres-dev
#   libopencv-superres4.2 libopencv-ts-dev libopencv-video-dev
#   libopencv-video4.2 libopencv-videoio-dev libopencv-videoio4.2
#   libopencv-videostab-dev libopencv-videostab4.2 libopencv-viz-dev
#   libopencv-viz4.2 libopencv4.2-java libopencv4.2-jni libopenexr-dev
#   libopenexr24 libopenjp2-7 libopenmpi3 libopenmpt0 libopus0 liborc-0.4-0
#   libpam-systemd libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpciaccess0 libperl5.30 libpixman-1-0 libpmix2 libpng-dev libpng16-16
#   libpoppler97 libpq5 libproj15 libprotobuf17 libproxy1v5 libpsl5
#   libpsm-infinipath1 libpsm2-2 libqhull7 libquadmath0 libraw1394-11
#   libraw1394-dev librdmacm1 librest-0.7-0 librsvg2-2 librsvg2-common librtmp1
#   libsensors-config libsensors5 libshine3 libsm6 libsnappy1v5 libsocket++1
#   libsoup-gnome2.4-1 libsoup2.4-1 libsoxr0 libspatialite7 libspeex1 libssh-4
#   libssh-gcrypt-4 libstdc++-9-dev libsuperlu5 libswresample-dev libswresample3
#   libswscale-dev libswscale5 libsz2 libtbb-dev libtbb2 libtesseract4
#   libthai-data libthai0 libtheora0 libtiff-dev libtiff5 libtiffxx5 libtsan0
#   libtwolame0 libubsan1 liburiparser1 libusb-1.0-0 libva-drm2 libva-x11-2
#   libva2 libvdpau1 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx6 libvtk6.3
#   libvulkan1 libwavpack1 libwayland-client0 libwayland-cursor0 libwayland-egl1
#   libwebp6 libwebpmux3 libx11-6 libx11-data libx11-xcb1 libx264-155
#   libx265-179 libxau6 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-render0 libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxdmcp6 libxerces-c3.2 libxext6
#   libxfixes3 libxi6 libxinerama1 libxkbcommon0 libxml2 libxnvctrl0 libxpm4
#   libxrandr2 libxrender1 libxshmfence1 libxslt1.1 libxt6 libxtables12
#   libxvidcore4 libxxf86vm1 libzvbi-common libzvbi0 linux-libc-dev make
#   mysql-common nginx-common nginx-core ocl-icd-libopencl1 odbcinst
#   odbcinst1debian2 patch perl perl-modules-5.30 pkg-config proj-data
#   shared-mime-info systemd systemd-sysv systemd-timesyncd tzdata ubuntu-mono
#   ucf x11-common xkb-data xz-utils zlib1g-dev
# Suggested packages:
#   binutils-doc cpp-doc gcc-9-locales debian-keyring g++-multilib
#   g++-9-multilib gcc-9-doc gcc-multilib manpages-dev autoconf automake libtool
#   flex bison gdb gcc-doc gcc-9-multilib iproute2-doc isoquery lrzip
#   libbluray-bdj glibc-doc locales colord cups-common git bzr libgd-tools
#   gdbm-l10n geotiff-bin gdal-bin libgeotiff-epsg gphoto2 krb5-doc krb5-user
#   libvisual-0.4-plugins gstreamer1.0-tools gvfs libhdf4-doc libhdf4-alt-dev
#   hdf4-tools libhwloc-contrib-plugins liblcms2-utils liblzma-doc libmyodbc
#   odbc-postgresql tdsodbc unixodbc-bin ogdi-bin opencv-doc opus-tools pciutils
#   proj-bin libraw1394-doc librsvg2-bin lm-sensors speex libstdc++-9-doc
#   libtbb-doc mpi-default-bin make-doc fcgiwrap nginx-doc ssl-cert opencl-icd
#   ed diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl libb-debug-perl liblocale-codes-perl
#   systemd-container policykit-1
# Recommended packages:
#   fakeroot libalgorithm-merge-perl libatm1 at-spi2-core libaacs0 manpages
#   manpages-dev libpam-cap dmsetup libfile-fcntllock-perl
#   liblocale-gettext-perl libexif-doc proj-bin libgdk-pixbuf2.0-bin
#   libglib2.0-data xdg-user-dirs libgphoto2-l10n gstreamer1.0-plugins-base
#   libgtk-3-bin ibverbs-providers krb5-locales opencv-data openmpi-bin
#   libpng-tools poppler-data publicsuffix libraw1394-tools va-driver-all
#   | va-driver vdpau-driver-all | vdpau-driver mesa-vulkan-drivers | vulkan-icd
#   networkd-dispatcher libnss-systemd
# The following NEW packages will be installed:
#   adwaita-icon-theme binutils binutils-common binutils-x86-64-linux-gnu
#   build-essential cpp cpp-9 curl dbus dbus-user-session
#   dconf-gsettings-backend dconf-service dpkg-dev fontconfig fontconfig-config
#   fonts-dejavu-core g++ g++-9 gcc gcc-9 gcc-9-base gdal-data glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme iproute2
#   iso-codes libaec0 libaom0 libapparmor1 libarchive13 libargon2-1
#   libarmadillo9 libarpack2 libasan5 libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatomic1 libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavcodec-dev libavcodec58
#   libavformat-dev libavformat58 libavresample-dev libavresample4 libavutil-dev
#   libavutil56 libbinutils libbluray2 libbrotli1 libbsd0 libc-dev-bin libc6-dev
#   libcairo-gobject2 libcairo2 libcap2 libcap2-bin libcc1-0 libcfitsio8
#   libcharls2 libchromaprint1 libcodec2-0.9 libcolord2 libcrypt-dev
#   libcryptsetup12 libctf-nobfd0 libctf0 libcups2 libcurl3-gnutls libcurl4
#   libdap25 libdapclient6v5 libdatrie1 libdbus-1-3 libdc1394-22
#   libdc1394-22-dev libdconf1 libdevmapper1.02.1 libdpkg-perl libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libedit2
#   libelf1 libepoxy0 libepsilon1 libevent-2.1-7 libevent-core-2.1-7
#   libevent-pthreads-2.1-7 libexif-dev libexif12 libexpat1 libfabric1
#   libfontconfig1 libfreetype6 libfreexl1 libfribidi0 libfyba0 libgcc-9-dev
#   libgd3 libgdal26 libgdbm-compat4 libgdbm6 libgdcm-dev libgdcm3.0
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-common libgeos-3.8.0 libgeos-c1v5
#   libgeotiff5 libgfortran5 libgif7 libgl1 libgl1-mesa-dri libgl2ps1.4
#   libglapi-mesa libglib2.0-0 libglvnd0 libglx-mesa0 libglx0 libgme0 libgomp1
#   libgphoto2-6 libgphoto2-dev libgphoto2-port12 libgraphite2-3 libgsm1
#   libgssapi-krb5-2 libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libgtk-3-0
#   libgtk-3-common libharfbuzz0b libhdf4-0-alt libhdf5-103 libhdf5-openmpi-103
#   libhwloc-plugins libhwloc15 libibverbs1 libice6 libicu66 libilmbase-dev
#   libilmbase24 libip4tc2 libisl22 libitm1 libjbig-dev libjbig0 libjpeg-dev
#   libjpeg-turbo8 libjpeg-turbo8-dev libjpeg8 libjpeg8-dev libjson-c4
#   libjson-glib-1.0-0 libjson-glib-1.0-common libjsoncpp1 libk5crypto3
#   libkeyutils1 libkmlbase1 libkmldom1 libkmlengine1 libkmod2 libkrb5-3
#   libkrb5support0 liblcms2-2 liblept5 libllvm11 liblsan0 libltdl7 liblzma-dev
#   libminizip1 libmnl0 libmp3lame0 libmpc3 libmpfr6 libmpg123-0
#   libmysqlclient21 libnetcdf-c++4 libnetcdf15 libnghttp2-14
#   libnginx-mod-http-image-filter libnginx-mod-http-xslt-filter
#   libnginx-mod-mail libnginx-mod-stream libnl-3-200 libnl-route-3-200 libnspr4
#   libnss3 libnuma1 libodbc1 libogdi4.1 libogg0 libopenblas-dev
#   libopenblas-pthread-dev libopenblas0 libopenblas0-pthread
#   libopencv-calib3d-dev libopencv-calib3d4.2 libopencv-contrib-dev
#   libopencv-contrib4.2 libopencv-core-dev libopencv-core4.2 libopencv-dev
#   libopencv-dnn-dev libopencv-dnn4.2 libopencv-features2d-dev
#   libopencv-features2d4.2 libopencv-flann-dev libopencv-flann4.2
#   libopencv-highgui-dev libopencv-highgui4.2 libopencv-imgcodecs-dev
#   libopencv-imgcodecs4.2 libopencv-imgproc-dev libopencv-imgproc4.2
#   libopencv-ml-dev libopencv-ml4.2 libopencv-objdetect-dev
#   libopencv-objdetect4.2 libopencv-photo-dev libopencv-photo4.2
#   libopencv-shape-dev libopencv-shape4.2 libopencv-stitching-dev
#   libopencv-stitching4.2 libopencv-superres-dev libopencv-superres4.2
#   libopencv-ts-dev libopencv-video-dev libopencv-video4.2
#   libopencv-videoio-dev libopencv-videoio4.2 libopencv-videostab-dev
#   libopencv-videostab4.2 libopencv-viz-dev libopencv-viz4.2 libopencv4.2-java
#   libopencv4.2-jni libopenexr-dev libopenexr24 libopenjp2-7 libopenmpi3
#   libopenmpt0 libopus0 liborc-0.4-0 libpam-systemd libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libperl5.30
#   libpixman-1-0 libpmix2 libpng-dev libpng16-16 libpoppler97 libpq5 libproj15
#   libprotobuf17 libproxy1v5 libpsl5 libpsm-infinipath1 libpsm2-2 libqhull7
#   libquadmath0 libraw1394-11 libraw1394-dev librdmacm1 librest-0.7-0
#   librsvg2-2 librsvg2-common librtmp1 libsensors-config libsensors5 libshine3
#   libsm6 libsnappy1v5 libsocket++1 libsoup-gnome2.4-1 libsoup2.4-1 libsoxr0
#   libspatialite7 libspeex1 libssh-4 libssh-gcrypt-4 libstdc++-9-dev
#   libsuperlu5 libswresample-dev libswresample3 libswscale-dev libswscale5
#   libsz2 libtbb-dev libtbb2 libtesseract4 libthai-data libthai0 libtheora0
#   libtiff-dev libtiff5 libtiffxx5 libtsan0 libtwolame0 libubsan1 liburiparser1
#   libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx6 libvtk6.3 libvulkan1 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3
#   libx11-6 libx11-data libx11-xcb1 libx264-155 libx265-179 libxau6
#   libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-render0
#   libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcb1 libxcomposite1 libxcursor1
#   libxdamage1 libxdmcp6 libxerces-c3.2 libxext6 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxml2 libxnvctrl0 libxpm4 libxrandr2 libxrender1
#   libxshmfence1 libxslt1.1 libxt6 libxtables12 libxvidcore4 libxxf86vm1
#   libzvbi-common libzvbi0 linux-libc-dev make mysql-common netbase nginx
#   nginx-common nginx-core ocl-icd-libopencl1 odbcinst odbcinst1debian2 patch
#   perl perl-modules-5.30 pkg-config proj-data shared-mime-info systemd
#   systemd-sysv systemd-timesyncd tzdata ubuntu-mono ucf wget x11-common
#   xkb-data xz-utils zlib1g-dev
# The following packages will be upgraded:
#   libc6
# 1 upgraded, 399 newly installed, 0 to remove and 18 not upgraded.
# Need to get 242 MB of archives.
# After this operation, 1408 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libxnvctrl0 460.32.03-0ubuntu1 [21.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc6 amd64 2.31-0ubuntu9.2 [2715 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libapparmor1 amd64 2.13.3-7ubuntu5.1 [34.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libcap2 amd64 1:2.32-1 [15.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libargon2-1 amd64 0~20171227-0.2 [19.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libdevmapper1.02.1 amd64 2:1.02.167-1ubuntu1 [127 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjson-c4 amd64 0.13.1+dfsg-7ubuntu0.3 [29.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcryptsetup12 amd64 2:2.2.2-3ubuntu2.3 [183 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libip4tc2 amd64 1.8.4-3ubuntu2 [18.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libkmod2 amd64 27-1ubuntu2 [44.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 systemd-timesyncd amd64 245.4-4ubuntu3.4 [28.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 systemd amd64 245.4-4ubuntu3.4 [3805 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 systemd-sysv amd64 245.4-4ubuntu3.4 [10.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 perl-modules-5.30 all 5.30.0-9ubuntu0.2 [2738 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdbm6 amd64 1.18.1-5 [27.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdbm-compat4 amd64 1.18.1-5 [6244 B]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libperl5.30 amd64 5.30.0-9ubuntu0.2 [3952 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 perl amd64 5.30.0-9ubuntu0.2 [224 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbus-1-3 amd64 1.12.16-2ubuntu2.1 [179 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libexpat1 amd64 2.2.9-1build1 [73.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dbus amd64 1.12.16-2ubuntu2.1 [151 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libbsd0 amd64 0.10.0-1 [45.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libelf1 amd64 0.176-1.1build1 [44.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libmnl0 amd64 1.0.4-2 [12.3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtables12 amd64 1.8.4-3ubuntu2 [28.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libcap2-bin amd64 1:2.32-1 [26.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 iproute2 amd64 5.5.0-1ubuntu1 [858 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libfribidi0 amd64 1.0.8-2 [23.8 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-0 amd64 2.64.6-1~ubuntu20.04.1 [1284 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 tzdata all 2021a-0ubuntu0.20.04 [295 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libicu66 amd64 66.1-2ubuntu2 [8520 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpam-systemd amd64 245.4-4ubuntu3.4 [186 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libxml2 amd64 2.9.10+dfsg-5 [640 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 netbase all 6.1 [13.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 shared-mime-info amd64 1.15-1 [430 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 ucf all 3.0038+nmu1 [51.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 xkb-data all 2.29-2 [349 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xz-utils amd64 5.2.4-1ubuntu1 [82.5 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 iso-codes all 4.4-1 [2695 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-common all 2.4.102-1ubuntu1~20.04.1 [5388 B]
# Get:41 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm2 amd64 2.4.102-1ubuntu1~20.04.1 [32.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libedit2 amd64 3.1-20191231-1 [87.0 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libkrb5support0 amd64 1.17-6ubuntu4.1 [30.9 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libk5crypto3 amd64 1.17-6ubuntu4.1 [79.9 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libkeyutils1 amd64 1.6-6ubuntu1 [10.2 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libkrb5-3 amd64 1.17-6ubuntu4.1 [330 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgssapi-krb5-2 amd64 1.17-6ubuntu4.1 [121 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/main amd64 libnuma1 amd64 2.0.12-1 [20.8 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/main amd64 libpng16-16 amd64 1.6.37-2 [179 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 libpsl5 amd64 0.21.0-1ubuntu1 [51.5 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/main amd64 libusb-1.0-0 amd64 2:1.0.23-2build1 [46.5 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 libxau6 amd64 1:1.0.9-0ubuntu1 [7488 B]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdmcp6 amd64 1:1.1.3-0ubuntu1 [10.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb1 amd64 1.14-2 [44.7 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-data all 2:1.6.9-2ubuntu1.1 [113 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-6 amd64 2:1.6.9-2ubuntu1.1 [574 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/main amd64 libxext6 amd64 2:1.3.4-0ubuntu1 [29.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 wget amd64 1.20.3-1ubuntu1 [349 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/main amd64 hicolor-icon-theme all 0.17-2 [9976 B]
# Get:60 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjpeg-turbo8 amd64 2.0.3-0ubuntu1.20.04.1 [117 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 libjpeg8 amd64 8c-2ubuntu8 [2194 B]
# Get:62 http://archive.ubuntu.com/ubuntu focal/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/main amd64 libwebp6 amd64 0.6.1-2 [185 kB]
# Get:64 http://archive.ubuntu.com/ubuntu focal/main amd64 libtiff5 amd64 4.1.0+git191117-2build1 [161 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-common all 2.40.0+dfsg-3ubuntu0.1 [4912 B]
# Get:66 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-0 amd64 2.40.0+dfsg-3ubuntu0.1 [169 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gtk-update-icon-cache amd64 3.24.20-0ubuntu1 [28.9 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfreetype6 amd64 2.10.1-2ubuntu0.1 [341 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-core all 2.37-1 [1041 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig-config all 2.13.1-2ubuntu3 [28.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontconfig1 amd64 2.13.1-2ubuntu3 [114 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal/main amd64 libpixman-1-0 amd64 0.38.4-0ubuntu1 [227 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0 amd64 1.14-2 [14.8 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0 amd64 1.14-2 [5584 B]
# Get:75 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrender1 amd64 1:0.9.10-1 [18.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2 amd64 1.16.0-4ubuntu1 [583 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo-gobject2 amd64 1.16.0-4ubuntu1 [17.2 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig amd64 2.13.1-2ubuntu3 [171 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphite2-3 amd64 1.3.13-11build1 [73.5 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/main amd64 libharfbuzz0b amd64 2.6.4-1ubuntu4 [391 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai-data all 0.1.28-3 [134 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 libdatrie1 amd64 0.2.12-3 [18.7 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai0 amd64 0.1.28-3 [18.1 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/main amd64 libpango-1.0-0 amd64 1.44.7-2ubuntu4 [162 kB]
# Get:85 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoft2-1.0-0 amd64 1.44.7-2ubuntu4 [34.9 kB]
# Get:86 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangocairo-1.0-0 amd64 1.44.7-2ubuntu4 [24.8 kB]
# Get:87 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 librsvg2-2 amd64 2.48.9-1ubuntu0.20.04.1 [2253 kB]
# Get:88 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 librsvg2-common amd64 2.48.9-1ubuntu0.20.04.1 [9212 B]
# Get:89 http://archive.ubuntu.com/ubuntu focal/main amd64 humanity-icon-theme all 0.6.15 [1250 kB]
# Get:90 http://archive.ubuntu.com/ubuntu focal/main amd64 ubuntu-mono all 19.04-0ubuntu3 [147 kB]
# Get:91 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 adwaita-icon-theme all 3.36.1-2ubuntu0.20.04.2 [3441 kB]
# Get:92 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 binutils-common amd64 2.34-6ubuntu1.1 [207 kB]
# Get:93 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libbinutils amd64 2.34-6ubuntu1.1 [475 kB]
# Get:94 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libctf-nobfd0 amd64 2.34-6ubuntu1.1 [47.1 kB]
# Get:95 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libctf0 amd64 2.34-6ubuntu1.1 [46.6 kB]
# Get:96 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.34-6ubuntu1.1 [1613 kB]
# Get:97 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 binutils amd64 2.34-6ubuntu1.1 [3380 B]
# Get:98 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc-dev-bin amd64 2.31-0ubuntu9.2 [71.8 kB]
# Get:99 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 linux-libc-dev amd64 5.4.0-65.73 [1116 kB]
# Get:100 http://archive.ubuntu.com/ubuntu focal/main amd64 libcrypt-dev amd64 1:4.4.10-10ubuntu4 [104 kB]
# Get:101 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc6-dev amd64 2.31-0ubuntu9.2 [2520 kB]
# Get:102 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gcc-9-base amd64 9.3.0-17ubuntu1~20.04 [19.1 kB]
# Get:103 http://archive.ubuntu.com/ubuntu focal/main amd64 libisl22 amd64 0.22.1-1 [592 kB]
# Get:104 http://archive.ubuntu.com/ubuntu focal/main amd64 libmpfr6 amd64 4.0.2-1 [240 kB]
# Get:105 http://archive.ubuntu.com/ubuntu focal/main amd64 libmpc3 amd64 1.1.0-1 [40.8 kB]
# Get:106 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 cpp-9 amd64 9.3.0-17ubuntu1~20.04 [7494 kB]
# Get:107 http://archive.ubuntu.com/ubuntu focal/main amd64 cpp amd64 4:9.3.0-1ubuntu2 [27.6 kB]
# Get:108 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcc1-0 amd64 10.2.0-5ubuntu1~20.04 [41.1 kB]
# Get:109 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgomp1 amd64 10.2.0-5ubuntu1~20.04 [102 kB]
# Get:110 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libitm1 amd64 10.2.0-5ubuntu1~20.04 [26.4 kB]
# Get:111 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libatomic1 amd64 10.2.0-5ubuntu1~20.04 [9300 B]
# Get:112 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libasan5 amd64 9.3.0-17ubuntu1~20.04 [394 kB]
# Get:113 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 liblsan0 amd64 10.2.0-5ubuntu1~20.04 [144 kB]
# Get:114 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtsan0 amd64 10.2.0-5ubuntu1~20.04 [320 kB]
# Get:115 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libubsan1 amd64 10.2.0-5ubuntu1~20.04 [136 kB]
# Get:116 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libquadmath0 amd64 10.2.0-5ubuntu1~20.04 [146 kB]
# Get:117 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgcc-9-dev amd64 9.3.0-17ubuntu1~20.04 [2360 kB]
# Get:118 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gcc-9 amd64 9.3.0-17ubuntu1~20.04 [8241 kB]
# Get:119 http://archive.ubuntu.com/ubuntu focal/main amd64 gcc amd64 4:9.3.0-1ubuntu2 [5208 B]
# Get:120 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libstdc++-9-dev amd64 9.3.0-17ubuntu1~20.04 [1714 kB]
# Get:121 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 g++-9 amd64 9.3.0-17ubuntu1~20.04 [8405 kB]
# Get:122 http://archive.ubuntu.com/ubuntu focal/main amd64 g++ amd64 4:9.3.0-1ubuntu2 [1604 B]
# Get:123 http://archive.ubuntu.com/ubuntu focal/main amd64 make amd64 4.2.1-1.2 [162 kB]
# Get:124 http://archive.ubuntu.com/ubuntu focal/main amd64 libdpkg-perl all 1.19.7ubuntu3 [230 kB]
# Get:125 http://archive.ubuntu.com/ubuntu focal/main amd64 patch amd64 2.7.6-6 [105 kB]
# Get:126 http://archive.ubuntu.com/ubuntu focal/main amd64 dpkg-dev all 1.19.7ubuntu3 [679 kB]
# Get:127 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 build-essential amd64 12.8ubuntu1.1 [4664 B]
# Get:128 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libbrotli1 amd64 1.0.7-6ubuntu0.1 [267 kB]
# Get:129 http://archive.ubuntu.com/ubuntu focal/main amd64 libnghttp2-14 amd64 1.40.0-1build1 [78.7 kB]
# Get:130 http://archive.ubuntu.com/ubuntu focal/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2build1 [54.9 kB]
# Get:131 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libssh-4 amd64 0.9.3-2ubuntu2.1 [170 kB]
# Get:132 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcurl4 amd64 7.68.0-1ubuntu2.4 [234 kB]
# Get:133 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 curl amd64 7.68.0-1ubuntu2.4 [161 kB]
# Get:134 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dbus-user-session amd64 1.12.16-2ubuntu2.1 [9428 B]
# Get:135 http://archive.ubuntu.com/ubuntu focal/main amd64 libdconf1 amd64 0.36.0-1 [37.4 kB]
# Get:136 http://archive.ubuntu.com/ubuntu focal/main amd64 dconf-service amd64 0.36.0-1 [29.8 kB]
# Get:137 http://archive.ubuntu.com/ubuntu focal/main amd64 dconf-gsettings-backend amd64 0.36.0-1 [22.5 kB]
# Get:138 http://archive.ubuntu.com/ubuntu focal/universe amd64 gdal-data all 3.0.4+dfsg-1build3 [186 kB]
# Get:139 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libproxy1v5 amd64 0.4.15-10ubuntu1.2 [49.1 kB]
# Get:140 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 glib-networking-common all 2.64.2-1ubuntu0.1 [5040 B]
# Get:141 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 glib-networking-services amd64 2.64.2-1ubuntu0.1 [10.6 kB]
# Get:142 http://archive.ubuntu.com/ubuntu focal/main amd64 gsettings-desktop-schemas all 3.36.0-1ubuntu1 [29.0 kB]
# Get:143 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 glib-networking amd64 2.64.2-1ubuntu0.1 [58.2 kB]
# Get:144 http://archive.ubuntu.com/ubuntu focal/universe amd64 libaec0 amd64 1.0.4-1 [19.1 kB]
# Get:145 http://archive.ubuntu.com/ubuntu focal/universe amd64 libaom0 amd64 1.0.0.errata1-3build1 [1160 kB]
# Get:146 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive13 amd64 3.4.0-2ubuntu1 [327 kB]
# Get:147 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgfortran5 amd64 10.2.0-5ubuntu1~20.04 [736 kB]
# Get:148 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libopenblas0-pthread amd64 0.3.8+ds-1ubuntu0.20.04.1 [9127 kB]
# Get:149 http://archive.ubuntu.com/ubuntu focal/universe amd64 libarpack2 amd64 3.7.0-3 [92.8 kB]
# Get:150 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsuperlu5 amd64 5.2.1+dfsg1-4 [159 kB]
# Get:151 http://archive.ubuntu.com/ubuntu focal/universe amd64 libarmadillo9 amd64 1:9.800.4+dfsg-1build1 [93.2 kB]
# Get:152 http://archive.ubuntu.com/ubuntu focal/main amd64 libatk1.0-data all 2.35.1-1ubuntu2 [2964 B]
# Get:153 http://archive.ubuntu.com/ubuntu focal/main amd64 libatk1.0-0 amd64 2.35.1-1ubuntu2 [45.5 kB]
# Get:154 http://archive.ubuntu.com/ubuntu focal/main amd64 libatspi2.0-0 amd64 2.36.0-2 [64.2 kB]
# Get:155 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libatk-bridge2.0-0 amd64 2.34.2-0ubuntu2~20.04.1 [58.2 kB]
# Get:156 http://archive.ubuntu.com/ubuntu focal/main amd64 libavahi-common-data amd64 0.7-4ubuntu7 [21.4 kB]
# Get:157 http://archive.ubuntu.com/ubuntu focal/main amd64 libavahi-common3 amd64 0.7-4ubuntu7 [21.7 kB]
# Get:158 http://archive.ubuntu.com/ubuntu focal/main amd64 libavahi-client3 amd64 0.7-4ubuntu7 [25.5 kB]
# Get:159 http://archive.ubuntu.com/ubuntu focal/universe amd64 libva2 amd64 2.7.0-2 [53.5 kB]
# Get:160 http://archive.ubuntu.com/ubuntu focal/universe amd64 libva-drm2 amd64 2.7.0-2 [7044 B]
# Get:161 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes3 amd64 1:5.0.3-2 [10.9 kB]
# Get:162 http://archive.ubuntu.com/ubuntu focal/universe amd64 libva-x11-2 amd64 2.7.0-2 [11.9 kB]
# Get:163 http://archive.ubuntu.com/ubuntu focal/main amd64 libvdpau1 amd64 1.3-1ubuntu2 [25.6 kB]
# Get:164 http://archive.ubuntu.com/ubuntu focal/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:165 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavutil56 amd64 7:4.2.4-1ubuntu0.1 [241 kB]
# Get:166 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcodec2-0.9 amd64 0.9.2-2 [7886 kB]
# Get:167 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgsm1 amd64 1.0.18-2 [24.4 kB]
# Get:168 http://archive.ubuntu.com/ubuntu focal/main amd64 libmp3lame0 amd64 3.100-3 [133 kB]
# Get:169 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopenjp2-7 amd64 2.3.1-1ubuntu4.20.04.1 [141 kB]
# Get:170 http://archive.ubuntu.com/ubuntu focal/main amd64 libopus0 amd64 1.3.1-0ubuntu1 [191 kB]
# Get:171 http://archive.ubuntu.com/ubuntu focal/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:172 http://archive.ubuntu.com/ubuntu focal/main amd64 libsnappy1v5 amd64 1.1.8-1build1 [16.7 kB]
# Get:173 http://archive.ubuntu.com/ubuntu focal/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu1 [53.2 kB]
# Get:174 http://archive.ubuntu.com/ubuntu focal/main amd64 libsoxr0 amd64 0.1.3-2build1 [78.0 kB]
# Get:175 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswresample3 amd64 7:4.2.4-1ubuntu0.1 [57.1 kB]
# Get:176 http://archive.ubuntu.com/ubuntu focal/main amd64 libogg0 amd64 1.3.4-0ubuntu1 [24.0 kB]
# Get:177 http://archive.ubuntu.com/ubuntu focal/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu2 [162 kB]
# Get:178 http://archive.ubuntu.com/ubuntu focal/main amd64 libtwolame0 amd64 0.4.0-2 [47.6 kB]
# Get:179 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbis0a amd64 1.3.6-2ubuntu1 [87.0 kB]
# Get:180 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbisenc2 amd64 1.3.6-2ubuntu1 [70.7 kB]
# Get:181 http://archive.ubuntu.com/ubuntu focal/main amd64 libvpx6 amd64 1.8.2-1build1 [820 kB]
# Get:182 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwavpack1 amd64 5.2.0-1ubuntu0.1 [77.3 kB]
# Get:183 http://archive.ubuntu.com/ubuntu focal/main amd64 libwebpmux3 amd64 0.6.1-2 [19.6 kB]
# Get:184 http://archive.ubuntu.com/ubuntu focal/universe amd64 libx264-155 amd64 2:0.155.2917+git0a84d98-2 [521 kB]
# Get:185 http://archive.ubuntu.com/ubuntu focal/universe amd64 libx265-179 amd64 3.2.1-1build1 [1060 kB]
# Get:186 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:187 http://archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi-common all 0.2.35-17 [32.5 kB]
# Get:188 http://archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi0 amd64 0.2.35-17 [237 kB]
# Get:189 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavcodec58 amd64 7:4.2.4-1ubuntu0.1 [4876 kB]
# Get:190 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavutil-dev amd64 7:4.2.4-1ubuntu0.1 [365 kB]
# Get:191 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswresample-dev amd64 7:4.2.4-1ubuntu0.1 [70.6 kB]
# Get:192 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavcodec-dev amd64 7:4.2.4-1ubuntu0.1 [5415 kB]
# Get:193 http://archive.ubuntu.com/ubuntu focal/universe amd64 libbluray2 amd64 1:1.2.0-1 [138 kB]
# Get:194 http://archive.ubuntu.com/ubuntu focal/universe amd64 libchromaprint1 amd64 1.4.3-3build1 [37.6 kB]
# Get:195 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgme0 amd64 0.6.2-1build1 [123 kB]
# Get:196 http://archive.ubuntu.com/ubuntu focal/main amd64 libmpg123-0 amd64 1.25.13-1 [124 kB]
# Get:197 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbisfile3 amd64 1.3.6-2ubuntu1 [16.1 kB]
# Get:198 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopenmpt0 amd64 0.4.11-1build1 [599 kB]
# Get:199 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libssh-gcrypt-4 amd64 0.9.3-2ubuntu2.1 [201 kB]
# Get:200 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavformat58 amd64 7:4.2.4-1ubuntu0.1 [981 kB]
# Get:201 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavformat-dev amd64 7:4.2.4-1ubuntu0.1 [1182 kB]
# Get:202 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavresample4 amd64 7:4.2.4-1ubuntu0.1 [54.2 kB]
# Get:203 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavresample-dev amd64 7:4.2.4-1ubuntu0.1 [64.1 kB]
# Get:204 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcurl3-gnutls amd64 7.68.0-1ubuntu2.4 [231 kB]
# Get:205 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcfitsio8 amd64 3.470-3 [466 kB]
# Get:206 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcharls2 amd64 2.0.0+dfsg-1build1 [74.1 kB]
# Get:207 http://archive.ubuntu.com/ubuntu focal/main amd64 liblcms2-2 amd64 2.9-4 [140 kB]
# Get:208 http://archive.ubuntu.com/ubuntu focal/main amd64 libcolord2 amd64 1.4.4-2 [133 kB]
# Get:209 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcups2 amd64 2.3.1-9ubuntu1.1 [233 kB]
# Get:210 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdap25 amd64 3.20.5-1 [435 kB]
# Get:211 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdapclient6v5 amd64 3.20.5-1 [92.2 kB]
# Get:212 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-amdgpu1 amd64 2.4.102-1ubuntu1~20.04.1 [18.4 kB]
# Get:213 http://archive.ubuntu.com/ubuntu focal/main amd64 libpciaccess0 amd64 0.16-0ubuntu1 [17.9 kB]
# Get:214 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-intel1 amd64 2.4.102-1ubuntu1~20.04.1 [60.3 kB]
# Get:215 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-nouveau2 amd64 2.4.102-1ubuntu1~20.04.1 [16.4 kB]
# Get:216 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-radeon1 amd64 2.4.102-1ubuntu1~20.04.1 [19.7 kB]
# Get:217 http://archive.ubuntu.com/ubuntu focal/main amd64 libepoxy0 amd64 1.5.4-1 [191 kB]
# Get:218 http://archive.ubuntu.com/ubuntu focal/universe amd64 libepsilon1 amd64 0.9.2+dfsg-4 [41.0 kB]
# Get:219 http://archive.ubuntu.com/ubuntu focal/main amd64 libevent-2.1-7 amd64 2.1.11-stable-1 [138 kB]
# Get:220 http://archive.ubuntu.com/ubuntu focal/main amd64 libevent-core-2.1-7 amd64 2.1.11-stable-1 [89.1 kB]
# Get:221 http://archive.ubuntu.com/ubuntu focal/main amd64 libevent-pthreads-2.1-7 amd64 2.1.11-stable-1 [7372 B]
# Get:222 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexif12 amd64 0.6.21-6ubuntu0.4 [78.6 kB]
# Get:223 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexif-dev amd64 0.6.21-6ubuntu0.4 [84.0 kB]
# Get:224 http://archive.ubuntu.com/ubuntu focal/main amd64 libnl-3-200 amd64 3.4.0-1 [53.9 kB]
# Get:225 http://archive.ubuntu.com/ubuntu focal/main amd64 libnl-route-3-200 amd64 3.4.0-1 [149 kB]
# Get:226 http://archive.ubuntu.com/ubuntu focal/main amd64 libibverbs1 amd64 28.0-1ubuntu1 [53.6 kB]
# Get:227 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpsm-infinipath1 amd64 3.3+20.604758e7-6 [168 kB]
# Get:228 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpsm2-2 amd64 11.2.86-1 [178 kB]
# Get:229 http://archive.ubuntu.com/ubuntu focal/main amd64 librdmacm1 amd64 28.0-1ubuntu1 [64.9 kB]
# Get:230 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfabric1 amd64 1.6.2-3 [396 kB]
# Get:231 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfyba0 amd64 4.1.1-6build1 [113 kB]
# Get:232 http://archive.ubuntu.com/ubuntu focal/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:233 http://archive.ubuntu.com/ubuntu focal/main amd64 libgd3 amd64 2.2.5-5.2ubuntu2 [118 kB]
# Get:234 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfreexl1 amd64 1.0.5-3 [33.4 kB]
# Get:235 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgeos-3.8.0 amd64 3.8.0-1build1 [535 kB]
# Get:236 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgeos-c1v5 amd64 3.8.0-1build1 [69.9 kB]
# Get:237 http://archive.ubuntu.com/ubuntu focal/universe amd64 proj-data all 6.3.1-1 [7647 kB]
# Get:238 http://archive.ubuntu.com/ubuntu focal/universe amd64 libproj15 amd64 6.3.1-1 [925 kB]
# Get:239 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgeotiff5 amd64 1.5.1-2 [53.1 kB]
# Get:240 http://archive.ubuntu.com/ubuntu focal/main amd64 libgif7 amd64 5.1.9-1 [32.2 kB]
# Get:241 http://archive.ubuntu.com/ubuntu focal/universe amd64 libhdf4-0-alt amd64 4.2.14-1ubuntu1 [268 kB]
# Get:242 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsz2 amd64 1.0.4-1 [5188 B]
# Get:243 http://archive.ubuntu.com/ubuntu focal/universe amd64 libhdf5-103 amd64 1.10.4+repack-11ubuntu1 [1311 kB]
# Get:244 http://archive.ubuntu.com/ubuntu focal/universe amd64 libminizip1 amd64 1.1-8build1 [20.2 kB]
# Get:245 http://archive.ubuntu.com/ubuntu focal/universe amd64 liburiparser1 amd64 0.9.3-2 [39.3 kB]
# Get:246 http://archive.ubuntu.com/ubuntu focal/universe amd64 libkmlbase1 amd64 1.3.0-8build1 [45.4 kB]
# Get:247 http://archive.ubuntu.com/ubuntu focal/universe amd64 libkmldom1 amd64 1.3.0-8build1 [152 kB]
# Get:248 http://archive.ubuntu.com/ubuntu focal/universe amd64 libkmlengine1 amd64 1.3.0-8build1 [72.5 kB]
# Get:249 http://archive.ubuntu.com/ubuntu focal/main amd64 mysql-common all 5.8+1.0.5ubuntu2 [7496 B]
# Get:250 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmysqlclient21 amd64 8.0.23-0ubuntu0.20.04.1 [1224 kB]
# Get:251 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnetcdf15 amd64 1:4.7.3-1 [341 kB]
# Get:252 http://archive.ubuntu.com/ubuntu focal/main amd64 libltdl7 amd64 2.4.6-14 [38.5 kB]
# Get:253 http://archive.ubuntu.com/ubuntu focal/main amd64 libodbc1 amd64 2.3.6-0.1build1 [189 kB]
# Get:254 http://archive.ubuntu.com/ubuntu focal/universe amd64 libogdi4.1 amd64 4.1.0+ds-1build1 [198 kB]
# Get:255 http://archive.ubuntu.com/ubuntu focal/main amd64 libnspr4 amd64 2:4.25-1 [107 kB]
# Get:256 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnss3 amd64 2:3.49.1-1ubuntu1.5 [1256 kB]
# Get:257 http://archive.ubuntu.com/ubuntu focal/main amd64 libpoppler97 amd64 0.86.1-0ubuntu1 [915 kB]
# Get:258 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpq5 amd64 12.6-0ubuntu0.20.04.1 [115 kB]
# Get:259 http://archive.ubuntu.com/ubuntu focal/universe amd64 libqhull7 amd64 2015.2-4 [152 kB]
# Get:260 http://archive.ubuntu.com/ubuntu focal/universe amd64 libspatialite7 amd64 4.3.0a-6build1 [1286 kB]
# Get:261 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxerces-c3.2 amd64 3.2.2+debian-1build3 [878 kB]
# Get:262 http://archive.ubuntu.com/ubuntu focal/main amd64 odbcinst amd64 2.3.6-0.1build1 [14.8 kB]
# Get:263 http://archive.ubuntu.com/ubuntu focal/main amd64 odbcinst1debian2 amd64 2.3.6-0.1build1 [41.1 kB]
# Get:264 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgdal26 amd64 3.0.4+dfsg-1build3 [6156 kB]
# Get:265 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsocket++1 amd64 1.12.13-10build1 [40.7 kB]
# Get:266 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgdcm3.0 amd64 3.0.5-1.1ubuntu2 [1871 kB]
# Get:267 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgdcm-dev amd64 3.0.5-1.1ubuntu2 [258 kB]
# Get:268 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglapi-mesa amd64 20.2.6-0ubuntu0.20.04.1 [26.7 kB]
# Get:269 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libllvm11 amd64 1:11.0.0-2~ubuntu20.04.1 [17.6 MB]
# Get:270 http://archive.ubuntu.com/ubuntu focal/main amd64 libsensors-config all 1:3.6.0-2ubuntu1 [6092 B]
# Get:271 http://archive.ubuntu.com/ubuntu focal/main amd64 libsensors5 amd64 1:3.6.0-2ubuntu1 [27.4 kB]
# Get:272 http://archive.ubuntu.com/ubuntu focal/main amd64 libvulkan1 amd64 1.2.131.2-1 [93.3 kB]
# Get:273 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dri amd64 20.2.6-0ubuntu0.20.04.1 [10.1 MB]
# Get:274 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd0 amd64 1.3.2-1~ubuntu0.20.04.1 [51.4 kB]
# Get:275 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-xcb1 amd64 2:1.6.9-2ubuntu1.1 [9220 B]
# Get:276 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri2-0 amd64 1.14-2 [6920 B]
# Get:277 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri3-0 amd64 1.14-2 [6552 B]
# Get:278 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-glx0 amd64 1.14-2 [22.1 kB]
# Get:279 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-present0 amd64 1.14-2 [5560 B]
# Get:280 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-sync1 amd64 1.14-2 [8884 B]
# Get:281 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-xfixes0 amd64 1.14-2 [9296 B]
# Get:282 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdamage1 amd64 1:1.1.5-2 [6996 B]
# Get:283 http://archive.ubuntu.com/ubuntu focal/main amd64 libxshmfence1 amd64 1.3-1 [5028 B]
# Get:284 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm1 amd64 1:1.1.4-1build1 [10.2 kB]
# Get:285 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx-mesa0 amd64 20.2.6-0ubuntu0.20.04.1 [142 kB]
# Get:286 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx0 amd64 1.3.2-1~ubuntu0.20.04.1 [32.6 kB]
# Get:287 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1 amd64 1.3.2-1~ubuntu0.20.04.1 [86.9 kB]
# Get:288 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgl2ps1.4 amd64 1.4.0+dfsg1-2 [38.2 kB]
# Get:289 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgphoto2-port12 amd64 2.5.25-0ubuntu0.1 [51.8 kB]
# Get:290 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgphoto2-6 amd64 2.5.25-0ubuntu0.1 [653 kB]
# Get:291 http://archive.ubuntu.com/ubuntu focal/main amd64 pkg-config amd64 0.29.1-0ubuntu4 [45.5 kB]
# Get:292 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgphoto2-dev amd64 2.5.25-0ubuntu0.1 [625 kB]
# Get:293 http://archive.ubuntu.com/ubuntu focal/main amd64 libgstreamer1.0-0 amd64 1.16.2-2 [890 kB]
# Get:294 http://archive.ubuntu.com/ubuntu focal/main amd64 liborc-0.4-0 amd64 1:0.4.31-1 [188 kB]
# Get:295 http://archive.ubuntu.com/ubuntu focal/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.16.2-4 [735 kB]
# Get:296 http://archive.ubuntu.com/ubuntu focal/main amd64 libjson-glib-1.0-common all 1.4.4-2ubuntu2 [3468 B]
# Get:297 http://archive.ubuntu.com/ubuntu focal/main amd64 libjson-glib-1.0-0 amd64 1.4.4-2ubuntu2 [59.4 kB]
# Get:298 http://archive.ubuntu.com/ubuntu focal/main amd64 libsoup2.4-1 amd64 2.70.0-1 [262 kB]
# Get:299 http://archive.ubuntu.com/ubuntu focal/main amd64 libsoup-gnome2.4-1 amd64 2.70.0-1 [6136 B]
# Get:300 http://archive.ubuntu.com/ubuntu focal/main amd64 librest-0.7-0 amd64 0.8.1-1 [32.2 kB]
# Get:301 http://archive.ubuntu.com/ubuntu focal/main amd64 libwayland-client0 amd64 1.18.0-1 [23.9 kB]
# Get:302 http://archive.ubuntu.com/ubuntu focal/main amd64 libwayland-cursor0 amd64 1.18.0-1 [10.3 kB]
# Get:303 http://archive.ubuntu.com/ubuntu focal/main amd64 libwayland-egl1 amd64 1.18.0-1 [5692 B]
# ...
# Setting up libopencv-stitching4.2:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-video-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-highgui-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-features2d-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-shape4.2:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-calib3d-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-objdetect-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-shape-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-superres-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-videostab-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-contrib4.2:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv4.2-jni (4.2.0+dfsg-5) ...
# Setting up libopencv-stitching-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv-contrib-dev:amd64 (4.2.0+dfsg-5) ...
# Setting up libopencv4.2-java (4.2.0+dfsg-5) ...
# Setting up libopencv-dev (4.2.0+dfsg-5) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.1) ...
# Processing triggers for systemd (245.4-4ubuntu3.4) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.40.0+dfsg-3ubuntu0.1) ...
# Removing intermediate container 9701a4818354
#  ---> d61f8fad1eb7
# Step 4/16 : ENV PYTHON_VERSION=3.6
#  ---> Running in 1e990d9eedf2
# Removing intermediate container 1e990d9eedf2
#  ---> ef30b2db9d3b
# Step 5/16 : ENV LANG=C.UTF-8 LC_ALL=C.UTF-8
#  ---> Running in d0524b175bb9
# Removing intermediate container d0524b175bb9
#  ---> 21723b379554
# Step 6/16 : ENV PATH /opt/conda/bin:$PATH
#  ---> Running in 8648572bc556
# Removing intermediate container 8648572bc556
#  ---> c181742407bd
# Step 7/16 : RUN wget --quiet https://repo.anaconda.com/miniconda/Miniconda3-4.5.12-Linux-x86_64.sh -O ~/miniconda.sh &&     /bin/bash ~/miniconda.sh -b -p /opt/conda &&     rm ~/miniconda.sh &&     /opt/conda/bin/conda install -y python=$PYTHON_VERSION
#  ---> Running in 8a74d862e7a4
# PREFIX=/opt/conda
# installing: python-3.7.1-h0371630_7 ...
# Python 3.7.1
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-1 ...
# installing: libgcc-ng-8.2.0-hdf63c60_1 ...
# installing: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-he6710b0_1 ...
# installing: openssl-1.1.1a-h7b6447c_0 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-h7b6447c_3 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-h7b6447c_5 ...
# installing: tk-8.6.8-hbc83047_0 ...
# installing: sqlite-3.26.0-h7b6447c_0 ...
# installing: asn1crypto-0.24.0-py37_0 ...
# installing: certifi-2018.11.29-py37_0 ...
# installing: chardet-3.0.4-py37_1 ...
# installing: idna-2.8-py37_0 ...
# installing: pycosat-0.6.3-py37h14c3975_0 ...
# installing: pycparser-2.19-py37_0 ...
# installing: pysocks-1.6.8-py37_0 ...
# installing: ruamel_yaml-0.15.46-py37h14c3975_0 ...
# installing: six-1.12.0-py37_0 ...
# installing: cffi-1.11.5-py37he75722e_1 ...
# installing: setuptools-40.6.3-py37_0 ...
# installing: cryptography-2.4.2-py37h1ba5d50_0 ...
# installing: wheel-0.32.3-py37_0 ...
# installing: pip-18.1-py37_0 ...
# installing: pyopenssl-18.0.0-py37_0 ...
# installing: urllib3-1.24.1-py37_0 ...
# installing: requests-2.21.0-py37_0 ...
# installing: conda-4.5.12-py37_0 ...
# installation finished.
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# readline-8.1         | 464 KB    | ########## | 100%
# sqlite-3.33.0        | 2.0 MB    | ########## | 100%
# libedit-3.1.20191231 | 121 KB    | ########## | 100%
# ca-certificates-2021 | 128 KB    | ########## | 100%
# certifi-2020.12.5    | 144 KB    | ########## | 100%
# setuptools-52.0.0    | 933 KB    | ########## | 100%
# python-3.6.12        | 34.0 MB   | ########## | 100%
# ld_impl_linux-64-2.3 | 645 KB    | ########## | 100%
# ncurses-6.2          | 1.1 MB    | ########## | 100%
# openssl-1.1.1j       | 3.8 MB    | ########## | 100%
# libffi-3.3           | 54 KB     | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
# pip-21.0.1           | 2.0 MB    | ########## | 100%
# wheel-0.36.2         | 31 KB     | ########## | 100%
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     readline-8.1               |       h27cfd23_0         464 KB
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     ca-certificates-2021.1.19  |       h06a4308_0         128 KB
#     certifi-2020.12.5          |   py36h06a4308_0         144 KB
#     setuptools-52.0.0          |   py36h06a4308_0         933 KB
#     python-3.6.12              |       hcff3b4d_2        34.0 MB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     openssl-1.1.1j             |       h27cfd23_0         3.8 MB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     _libgcc_mutex-0.1          |             main           3 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     pip-21.0.1                 |   py36h06a4308_0         2.0 MB
#     wheel-0.36.2               |     pyhd3eb1b0_0          31 KB
#     ------------------------------------------------------------
#                                            Total:        57.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:    0.1-main
#     ld_impl_linux-64: 2.33.1-h53a641e_7
#
# The following packages will be UPDATED:
#
#     ca-certificates:  2018.03.07-0            --> 2021.1.19-h06a4308_0
#     certifi:          2018.11.29-py37_0       --> 2020.12.5-py36h06a4308_0
#     libedit:          3.1.20170329-h6b74fdf_2 --> 3.1.20191231-h14c3975_1
#     libffi:           3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:        8.2.0-hdf63c60_1        --> 9.1.0-hdf63c60_0
#     ncurses:          6.1-he6710b0_1          --> 6.2-he6710b0_1
#     openssl:          1.1.1a-h7b6447c_0       --> 1.1.1j-h27cfd23_0
#     pip:              18.1-py37_0             --> 21.0.1-py36h06a4308_0
#     readline:         7.0-h7b6447c_5          --> 8.1-h27cfd23_0
#     setuptools:       40.6.3-py37_0           --> 52.0.0-py36h06a4308_0
#     sqlite:           3.26.0-h7b6447c_0       --> 3.33.0-h62c20be_0
#     tk:               8.6.8-hbc83047_0        --> 8.6.10-hbc83047_0
#     wheel:            0.32.3-py37_0           --> 0.36.2-pyhd3eb1b0_0
#     xz:               5.2.4-h14c3975_4        --> 5.2.5-h7b6447c_0
#
# The following packages will be DOWNGRADED:
#
#     python:           3.7.1-h0371630_7        --> 3.6.12-hcff3b4d_2
#
#
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Removing intermediate container 8a74d862e7a4
#  ---> f6f59840dccc
# Step 8/16 : RUN pip install tensorflow-gpu
#  ---> Running in 14f06e49ac96
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.4.1-cp36-cp36m-manylinux2010_x86_64.whl (394.3 MB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.6/site-packages (from tensorflow-gpu) (0.36.2)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.15.0-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp36-cp36m-manylinux2014_x86_64.whl (3.8 MB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.27.0-py2.py3-none-any.whl (135 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard~=2.4->tensorflow-gpu) (52.0.0.post20210125)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.1-py3-none-any.whl (36 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2020.12.5)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=7190f5952c1fded1e30d1cd29b50e306d9e8abbd4c5222b3c10fcc23410da26d
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=76001 sha256=07b17ad6d0426d1e45d870477f9a77cc8e0fbff00ab1c0451a689a513264bc1a
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built termcolor wrapt
# Installing collected packages: urllib3, pyasn1, idna, chardet, zipp, typing-extensions, six, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow-gpu
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.2.1 chardet-4.0.0 flatbuffers-1.12 gast-0.3.3 google-auth-1.27.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 idna-2.10 importlib-metadata-3.4.0 keras-preprocessing-1.1.2 markdown-3.3.3 numpy-1.19.5 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.15.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.25.1 requests-oauthlib-1.3.0 rsa-4.7.1 six-1.15.0 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-estimator-2.4.0 tensorflow-gpu-2.4.1 termcolor-1.1.0 typing-extensions-3.7.4.3 urllib3-1.26.3 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.4.0
# Removing intermediate container 14f06e49ac96
#  ---> a467d035813a
# Step 9/16 : RUN pip install scipy pillow gunicorn==19.9.0 gevent flask
#  ---> Running in 1bf3ff3061af
# Collecting scipy
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting pillow
#   Downloading Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting gevent
#   Downloading gevent-21.1.2-cp36-cp36m-manylinux2010_x86_64.whl (5.5 MB)
# Collecting flask
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/conda/lib/python3.6/site-packages (from flask) (1.0.1)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.2.0-cp36-cp36m-manylinux2010_x86_64.whl (236 kB)
# Collecting greenlet<2.0,>=0.4.17
#   Downloading greenlet-1.0.0-cp36-cp36m-manylinux2010_x86_64.whl (156 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from gevent) (52.0.0.post20210125)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.6/site-packages (from scipy) (1.19.5)
# Installing collected packages: MarkupSafe, zope.interface, zope.event, Jinja2, itsdangerous, greenlet, click, scipy, pillow, gunicorn, gevent, flask
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 click-7.1.2 flask-1.1.2 gevent-21.1.2 greenlet-1.0.0 gunicorn-19.9.0 itsdangerous-1.1.0 pillow-8.1.0 scipy-1.5.4 zope.event-4.5.0 zope.interface-5.2.0
# Removing intermediate container 1bf3ff3061af
#  ---> 42dc72f1e530
# Step 10/16 : ENV PYTHONUNBUFFERED=TRUE
#  ---> Running in b6f075af79d6
# Removing intermediate container b6f075af79d6
#  ---> b510d8e858e0
# Step 11/16 : ENV PYTHONDONTWRITEBYTECODE=TRUE
#  ---> Running in 80868afda9e2
# Removing intermediate container 80868afda9e2
#  ---> 5062422428e6
# Step 12/16 : ENV PATH="/opt/program:${PATH}"
#  ---> Running in 47e307ff3059
# Removing intermediate container 47e307ff3059
#  ---> 9339ebf70528
# Step 13/16 : COPY ./scripts /opt/program
#  ---> 68ba5e45067a
# Step 14/16 : RUN chmod +x /opt/program/train
#  ---> Running in 09ca8a006fca
# Removing intermediate container 09ca8a006fca
#  ---> aa4d7a73975e
# Step 15/16 : RUN chmod +x /opt/program/serve
#  ---> Running in 8615d174a782
# Removing intermediate container 8615d174a782
#  ---> f697c945eb59
# Step 16/16 : WORKDIR /opt/program
#  ---> Running in 8de19040ff44
# Removing intermediate container 8de19040ff44
#  ---> 1075c69f9eb9
# Successfully built 1075c69f9eb9
# Successfully tagged k-fruits-class-gpu:latest

# %%
# !docker tag $image_tag $account.dkr.ecr.$region.amazonaws.com/$repo_name:latest

# %%
 # !docker images
# Out:
# REPOSITORY                                                   TAG                                 IMAGE ID            CREATED             SIZE
# 470086202700.dkr.ecr.us-east-1.amazonaws.com/k-fruit-class   latest                              1075c69f9eb9        30 seconds ago      6.73GB
# k-fruits-class-gpu                                           latest                              1075c69f9eb9        30 seconds ago      6.73GB
# nvidia/cuda                                                  11.2.1-cudnn8-runtime-ubuntu20.04   564cde45cf27        7 days ago          3.35GB

# %%
 # !docker push $account.dkr.ecr.$region.amazonaws.com/$repo_name:latest
# Out:
# The push refers to repository [470086202700.dkr.ecr.us-east-1.amazonaws.com/k-fruit-class]
#
# 27de4d30: Preparing
# 983c8ef1: Preparing
# 71b90591: Preparing
# a2582e8d: Preparing
# faa3bcd3: Preparing
# 53a66833: Preparing
# 18e8601c: Preparing
# 9ad2e494: Preparing
# c89a68e7: Preparing
# f8b0d5dc: Preparing
# 54026d32: Preparing
# 219e55ec: Preparing
# e4fae76c: Preparing
# 3afd360b: Preparing
# c0f42a39: Preparing
# aa3bcd3: Pushing  824.6MB/1.503GBPushing  548.8MB/586.2MBPushing  706.5MB/1.503GBPushing  664.3MB/1.136GBPushing  742.1MB/1.503GBaa3bcd3: Pushed   1.514GB/1.503GBlatest: digest: sha256:14c83b87318175b6adc508615c814384cabc8d18c3a349cd2888319a059be7d5 size: 3685

# %% [markdown]
# ### Upload data to S3 bucket from local repo if data is already in s3 just provide the paths of s3

# %%
local_directory = 'data'
prefix          = repo_name+'/input'

#train_input_path      = sess.upload_data(local_directory+'/training/',      key_prefix=prefix+'/train')
#validation_input_path = sess.upload_data(local_directory+'/validation/', key_prefix=prefix+'/validation')

# %%
train_input_path="s3://sagemaker-us-east-1-470086202700/k-fruit-class/input/train"
validation_input_path="s3://sagemaker-us-east-1-470086202700/k-fruit-class/input/validation"

# %% [markdown]
# ### Run Below cell if the image is already built and you know the name otherwise uncomment the commented part

# %%
#output_path = 's3://{}/{}/output'.format(sess.default_bucket(), repo_name)
#image_name  = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, repo_name)
output_path="s3://sagemaker-us-east-1-470086202700/k-fruit-class/output"
image_name="470086202700.dkr.ecr.us-east-1.amazonaws.com/k-fruit-class:latest"
print(output_path)
print(image_name)
# Out:
# s3://sagemaker-us-east-1-470086202700/k-fruit-class/output
# 470086202700.dkr.ecr.us-east-1.amazonaws.com/k-fruit-class:latest

# %% [markdown]
# ## Set up estimator and run the traning

# %%
estimator = sagemaker.estimator.Estimator(
                       image_uri=image_name,
                       base_job_name=base_job_name,
                       role=role, 
                       instance_count=1, 
                       instance_type="local-gpu",
                       output_path=output_path,
                       sagemaker_session=sess,
                       hyperparameters={
                              'epochs': 20,
                              'batch-size': 256,
                              'lr': 0.01}
                        )

# %%
estimator.fit({'training': train_input_path, 'validation': validation_input_path})
# Out:
# KeyboardInterrupt

# %% [markdown]
# ### Deploy the trained model weights

# %%
predictor=estimator.deploy(initial_instance_count=1,instance_type="ml.m4.xlarge")
# Out:
# -------------------!

# %%
from PIL import Image
import numpy as np
import json

# %%
image_path="data/training/Banana/176_100.jpg"
img=np.array(Image.open(image_path))
if img is None:
    raise("Image cannot be loaded")
data={"images":img.tolist(),"batch_size":1}
json_data=json.dumps(data)
res=predictor.predict(json_data)
res

# %%
## Delete the endpoint if not needed anymore

# %%
predictor.delete_endpoint()
